# %%
# %cd drive/MyDrive/noval-seam-carving-method/
# Out:
# /content/drive/MyDrive/noval-seam-carving-method

# %%
from myfunctions import SM_creator, GM_creator, DM_creator
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# # Generate Gradient Map

# %%
model_path = 'final-models/bdcn_bsds500.pth'
img_folder = './images'
img_path = './images/view1.png'
cuda = True

# %%
gradient_map = GM_creator(img_folder, img_path, model_path, cuda)
plt.imshow(gradient_map, cmap='gray')
plt.show()
# Out:
# /content/drive/My Drive/noval-seam-carving-method/GM_src/bdcn2.py:199: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   nn.init.constant(param, 0.080)

# %% [markdown]
# # Generate Saliency Map

# %%
device = torch.device(device='cuda')
img_folder='./images'
img_path = 'images/view1.png'
model_path='final-models/best-model.pth'
img_size = 256
bs = 24

# %%
saliency_map = SM_creator(img_folder, img_path, model_path, img_size, bs, device)
plt.imshow(saliency_map, cmap='gray')
plt.show()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# # Read Depth Map

# %%
img_path = 'depth_map/disp1.png'

# %%
depth_map = DM_creator(img_path)
plt.imshow(depth_map, cmap='gray')
plt.show()
